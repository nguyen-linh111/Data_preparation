# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
train_data = pd.read_csv("/content/drive/MyDrive/data/train.csv", sep = ";")
test_data = pd.read_csv("/content/drive/MyDrive/data/test.csv", sep = ";")

# %% [markdown]
# ## Train_data

# %%
train_data.head()
# Out:
#                              name  year  ...                  torque  seats
# 0      Tata Nexon 1.5 Revotorq XM  2018  ...     260Nm@ 1500-2750rpm    5.0
# 1    Hyundai i20 Active SX Diesel  2018  ...  219.66nm@ 1500-2750rpm    5.0
# 2          Toyota Fortuner 4x2 AT  2015  ...     360Nm@ 1400-3200rpm    7.0
# 3       Hyundai Verna 1.6 VTVT SX  2015  ...        154.9Nm@ 4200rpm    5.0
# 4  Volvo XC40 D4 Inscription BSIV  2019  ...                   400Nm    5.0
#
# [5 rows x 13 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6000 non-null   object
#  1   year           6000 non-null   int64
#  2   selling_price  6000 non-null   int64
#  3   km_driven      6000 non-null   int64
#  4   fuel           6000 non-null   object
#  5   seller_type    6000 non-null   object
#  6   transmission   6000 non-null   object
#  7   owner          6000 non-null   object
#  8   mileage        5841 non-null   object
#  9   engine         5841 non-null   object
#  10  max_power      5846 non-null   object
#  11  torque         5840 non-null   object
#  12  seats          5841 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 609.5+ KB

# %%
train_data.shape
# Out:
# (6000, 13)

# %%
train_data.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  6000.000000   6.000000e+03  6.000000e+03  5841.000000
# mean   2013.814833   6.387764e+05  6.997216e+04     5.429550
# std       4.026733   8.066632e+05  5.188961e+04     0.977071
# min    1983.000000   3.000000e+04  1.000000e+03     2.000000
# 25%    2011.000000   2.557498e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.900000e+04     5.000000
# max    2020.000000   1.000000e+07  1.500000e+06    14.000000

# %%
print(train_data['fuel'].unique())
print(train_data['transmission'].unique())
print(train_data['owner'].unique())
# Out:
# ['Diesel' 'Petrol' 'LPG' 'CNG']
# ['Manual' 'Automatic']
# ['First Owner' 'Second Owner' 'Third Owner' 'Fourth & Above Owner'
#  'Test Drive Car']

# %%
train_data.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          159
# engine           159
# max_power        154
# torque           160
# seats            159
# dtype: int64

# %%
train_data['brand'] = train_data['name'].apply(lambda x: x.split()[0])
train_data.brand.value_counts()
# Out:
# Maruti           1792
# Hyundai          1034
# Mahindra          595
# Tata              546
# Toyota            366
# Honda             335
# Ford              288
# Chevrolet         170
# Renault           164
# Volkswagen        136
# BMW                83
# Skoda              77
# Nissan             60
# Jaguar             52
# Volvo              50
# Datsun             49
# Mercedes-Benz      44
# Fiat               38
# Audi               30
# Lexus              27
# Jeep               23
# Mitsubishi         12
# Land                6
# Force               5
# Isuzu               5
# Kia                 4
# Ambassador          3
# Daewoo              2
# Peugeot             1
# Ashok               1
# MG                  1
# Opel                1
# Name: brand, dtype: int64

# %%
var = 'brand'
data = pd.concat([train_data['selling_price'], train_data[var]], axis=1)
f, ax = plt.subplots(figsize=(36, 16))
fig = sns.boxplot(x=var, y="selling_price", data=data)
fig.axis(ymin=0);

# %%
luxury_brand = ['Volvo', 'BMW','Jaguar', 'Audi','Mercedes-Benz','Isuzu','Lexus','Land']
train_data['brand'] = train_data['name'].apply(lambda x: 'Luxury' if x.split()[0] in luxury_brand else 'Popularly')
'''
1: Luxury brand
2: Popularly brand
'''
train_data.brand.value_counts()
# Out:
# Popularly    5703
# Luxury        297
# Name: brand, dtype: int64

# %%
brand = train_data['brand']
brand = pd.get_dummies(brand, drop_first=True)
brand.head()
# Out:
#    Popularly
# 0          1
# 1          1
# 2          1
# 3          1
# 4          0

# %%
train_data['mileage_n']=train_data.mileage.str.extract(r'(\d+.\d+)').astype('float')
train_data['engine_n']=train_data.engine.str.extract(r'(\d+.\d+)').astype('float')
train_data['max_power_n']=train_data.max_power.str.extract(r'(\d+.\d+)').astype('float')

# %%
train_data.head()
# Out:
#                              name  year  ...  engine_n  max_power_n
# 0      Tata Nexon 1.5 Revotorq XM  2018  ...    1497.0       108.50
# 1    Hyundai i20 Active SX Diesel  2018  ...    1396.0        88.76
# 2          Toyota Fortuner 4x2 AT  2015  ...    2982.0       168.50
# 3       Hyundai Verna 1.6 VTVT SX  2015  ...    1591.0       121.30
# 4  Volvo XC40 D4 Inscription BSIV  2019  ...    1969.0       190.00
#
# [5 rows x 17 columns]

# %%
train_data = train_data.reset_index(drop=True)

# %%
train_data.shape
# Out:
# (6000, 17)

# %%
train_data["years_driven"]=int(2021)-train_data['year']

# %%
train_data.drop(["name"],axis=1,inplace=True)
train_data.drop(["mileage"],axis=1,inplace=True)
train_data.drop(["engine"],axis=1,inplace=True)
train_data.drop(["max_power"],axis=1,inplace=True)
train_data.drop(["torque"],axis=1,inplace=True)
train_data.drop(["year"],axis=1,inplace=True)

# %%
train_data.head()
# Out:
#    selling_price  km_driven    fuel  ... engine_n max_power_n years_driven
# 0         850000       9500  Diesel  ...   1497.0      108.50            3
# 1         750000      30000  Diesel  ...   1396.0       88.76            3
# 2        1500000      80000  Diesel  ...   2982.0      168.50            6
# 3         795000      35000  Petrol  ...   1591.0      121.30            6
# 4        3800000      20000  Diesel  ...   1969.0      190.00            2
#
# [5 rows x 12 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   selling_price  6000 non-null   int64
#  1   km_driven      6000 non-null   int64
#  2   fuel           6000 non-null   object
#  3   seller_type    6000 non-null   object
#  4   transmission   6000 non-null   object
#  5   owner          6000 non-null   object
#  6   seats          5841 non-null   float64
#  7   brand          6000 non-null   object
#  8   mileage_n      5841 non-null   float64
#  9   engine_n       5841 non-null   float64
#  10  max_power_n    4437 non-null   float64
#  11  years_driven   6000 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 562.6+ KB

# %%
train_data = train_data.fillna(train_data.mean())

# %% [markdown]
# ##Visualization

# %%
fig = plt.figure(figsize = (15,15))
ax = fig.gca()
train_data.plot(kind='box', subplots=True, layout=(4,4), sharex=False, sharey=False, fontsize=8, ax=ax)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py:61: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   plot_obj.generate()

# %%
var = 'fuel'
data = pd.concat([train_data['selling_price'], train_data[var]], axis=1)
f, ax = plt.subplots(figsize=(12, 8))
fig = sns.boxplot(x=var, y="selling_price", data=data)
fig.axis(ymin=0);

# %%
var = 'years_driven'
data = pd.concat([train_data['selling_price'], train_data[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 10))
fig = sns.boxplot(x=var, y="selling_price", data=data)
fig.axis(ymin=0);
plt.xticks(rotation=90);

# %%
var = 'owner'
data = pd.concat([train_data['selling_price'], train_data[var]], axis=1)
f, ax = plt.subplots(figsize=(12, 8))
fig = sns.boxplot(x=var, y="selling_price", data=data)
fig.axis(ymin=0);

# %%
var = 'transmission'
data = pd.concat([train_data['selling_price'], train_data[var]], axis=1)
f, ax = plt.subplots(figsize=(12, 8))
fig = sns.boxplot(x=var, y="selling_price", data=data)
fig.axis(ymin=0);

# %%
var = 'seats'
data = pd.concat([train_data['selling_price'], train_data[var]], axis=1)
f, ax = plt.subplots(figsize=(12, 8))
fig = sns.boxplot(x=var, y="selling_price", data=data)
fig.axis(ymin=0);

# %% [markdown]
# ##Categorical Data

# %%
var = 'fuel'
train_data[var].value_counts()
# Out:
# Diesel    3265
# Petrol    2664
# CNG         44
# LPG         27
# Name: fuel, dtype: int64

# %%
fuel_t = train_data[[var]]
fuel_t = pd.get_dummies(fuel_t, drop_first=True)
fuel_t.head()
# Out:
#    fuel_Diesel  fuel_LPG  fuel_Petrol
# 0            1         0            0
# 1            1         0            0
# 2            1         0            0
# 3            0         0            1
# 4            1         0            0

# %%
var = 'transmission'
train_data[var].value_counts()
# Out:
# Manual       5228
# Automatic     772
# Name: transmission, dtype: int64

# %%
transmission = train_data[[var]]
transmission = pd.get_dummies(transmission, drop_first=True)
transmission.head()
# Out:
#    transmission_Manual
# 0                    1
# 1                    1
# 2                    0
# 3                    1
# 4                    0

# %%
var = 'seller_type'
train_data[var].value_counts()
# Out:
# Individual          5006
# Dealer               820
# Trustmark Dealer     174
# Name: seller_type, dtype: int64

# %%
seller_type = train_data[[var]]
seller_type = pd.get_dummies(seller_type, drop_first=True)
seller_type.head()
# Out:
#    seller_type_Individual  seller_type_Trustmark Dealer
# 0                       1                             0
# 1                       1                             0
# 2                       1                             0
# 3                       1                             0
# 4                       1                             0

# %%
var = 'owner'
train_data[var].value_counts()
# Out:
# First Owner             3904
# Second Owner            1558
# Third Owner              414
# Fourth & Above Owner     119
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
train_data.replace({"First Owner":1,"Second Owner":2,"Third Owner": 3,"Fourth & Above Owner":4,"Test Drive Car":5},inplace=True)
train_data.head()
# Out:
#    selling_price  km_driven    fuel  ... engine_n max_power_n  years_driven
# 0         850000       9500  Diesel  ...   1497.0      108.50             3
# 1         750000      30000  Diesel  ...   1396.0       88.76             3
# 2        1500000      80000  Diesel  ...   2982.0      168.50             6
# 3         795000      35000  Petrol  ...   1591.0      121.30             6
# 4        3800000      20000  Diesel  ...   1969.0      190.00             2
#
# [5 rows x 12 columns]

# %%
final_train= pd.concat([train_data,fuel_t,transmission,seller_type, brand],axis=1)
final_train.head()
# Out:
#    selling_price  km_driven  ... seller_type_Trustmark Dealer Popularly
# 0         850000       9500  ...                            0         1
# 1         750000      30000  ...                            0         1
# 2        1500000      80000  ...                            0         1
# 3         795000      35000  ...                            0         1
# 4        3800000      20000  ...                            0         0
#
# [5 rows x 19 columns]

# %%
final_train.drop(["fuel","transmission","seller_type","brand"],axis=1,inplace=True)
final_train.head()
# Out:
#    selling_price  km_driven  ...  seller_type_Trustmark Dealer  Popularly
# 0         850000       9500  ...                             0          1
# 1         750000      30000  ...                             0          1
# 2        1500000      80000  ...                             0          1
# 3         795000      35000  ...                             0          1
# 4        3800000      20000  ...                             0          0
#
# [5 rows x 15 columns]

# %%
final_train.shape
# Out:
# (6000, 15)

# %% [markdown]
# ## Test_data

# %%
test_data.head()
# Out:
#    Id                                     name  ...               torque  seats
# 0   1          Skoda Rapid 1.6 MPI AT Elegance  ...       153Nm@ 3800rpm    5.0
# 1   2                      Honda City i VTEC V  ...       145Nm@ 4600rpm    5.0
# 2   3        Hyundai Xcent 1.2 Kappa SX Option  ...       114Nm@ 4000rpm    5.0
# 3   4  Mahindra Scorpio 2009-2014 SLE 7S BSIII  ...  290Nm@ 1800-2800rpm    7.0
# 4   5        Ford Ecosport 1.5 Diesel Titanium  ...  215Nm@ 1750-2500rpm    5.0
#
# [5 rows x 13 columns]

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2128 entries, 0 to 2127
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            2128 non-null   int64
#  1   name          2128 non-null   object
#  2   year          2128 non-null   int64
#  3   km_driven     2128 non-null   int64
#  4   fuel          2128 non-null   object
#  5   seller_type   2128 non-null   object
#  6   transmission  2128 non-null   object
#  7   owner         2128 non-null   object
#  8   mileage       2066 non-null   object
#  9   engine        2066 non-null   object
#  10  max_power     2067 non-null   object
#  11  torque        2066 non-null   object
#  12  seats         2066 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 216.2+ KB

# %%
test_data['mileage_n']= test_data.mileage.str.extract(r'(\d+.\d+)').astype('float')
test_data['engine_n']= test_data.engine.str.extract(r'(\d+.\d+)').astype('float')
test_data['max_power_n']= test_data.max_power.str.extract(r'(\d+.\d+)').astype('float')

# %%
test_data = test_data.reset_index(drop=True)

# %%
test_data.head()
# Out:
#    Id                                     name  ...  engine_n  max_power_n
# 0   1          Skoda Rapid 1.6 MPI AT Elegance  ...    1598.0       103.50
# 1   2                      Honda City i VTEC V  ...    1497.0       117.30
# 2   3        Hyundai Xcent 1.2 Kappa SX Option  ...    1197.0          NaN
# 3   4  Mahindra Scorpio 2009-2014 SLE 7S BSIII  ...    2179.0       120.00
# 4   5        Ford Ecosport 1.5 Diesel Titanium  ...    1498.0        98.96
#
# [5 rows x 16 columns]

# %%
test_data["years_driven"]=int(2021)-test_data['year']

# %%
test_data['brand'] = test_data['name'].apply(lambda x: x.split()[0])
luxury_brand = ['Volvo', 'BMW','Jaguar', 'Audi','Mercedes-Benz','Isuzu','Lexus','Land']
test_data['brand'] = test_data['name'].apply(lambda x: 'Luxury' if x.split()[0] in luxury_brand else 'Popularly')
brand = test_data['brand']
brand = pd.get_dummies(brand, drop_first=True)
brand.head()
# Out:
#    Popularly
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
test_data.drop(["Id"],axis=1,inplace=True)
test_data.drop(["name"],axis=1,inplace=True)
test_data.drop(["torque"],axis=1,inplace=True)
test_data.drop(["mileage"],axis=1,inplace=True)
test_data.drop(["engine"],axis=1,inplace=True)
test_data.drop(["max_power"],axis=1,inplace=True)
test_data.drop(["year"],axis=1,inplace=True)

# %%
test_data = test_data.fillna(test_data.mean())

# %%
var = 'fuel'
fuel_t = test_data[[var]]
fuel_t = pd.get_dummies(fuel_t, drop_first=True)

var = 'transmission'
transmission = test_data[[var]]
transmission = pd.get_dummies(transmission, drop_first=True)

var = 'seller_type'
seller_type = test_data[[var]]
seller_type = pd.get_dummies(seller_type, drop_first=True)

var = 'owner'
test_data.replace({"First Owner":1,"Second Owner":2,"Third Owner": 3,"Fourth & Above Owner":4,"Test Drive Car":5},inplace=True)
test_data.head()
# Out:
#    km_driven    fuel seller_type  ... max_power_n  years_driven      brand
# 0      11000  Petrol      Dealer  ...  103.500000             5  Popularly
# 1      35000  Petrol  Individual  ...  117.300000             4  Popularly
# 2      80000  Petrol  Individual  ...   97.652087             7  Popularly
# 3     145241  Diesel  Individual  ...  120.000000             7  Popularly
# 4      92651  Diesel      Dealer  ...   98.960000             6  Popularly
#
# [5 rows x 11 columns]

# %%
final_test= pd.concat([test_data,fuel_t,transmission,seller_type,brand],axis=1)
final_test.head()
# Out:
#    km_driven    fuel  ... seller_type_Trustmark Dealer Popularly
# 0      11000  Petrol  ...                            0         1
# 1      35000  Petrol  ...                            0         1
# 2      80000  Petrol  ...                            0         1
# 3     145241  Diesel  ...                            0         1
# 4      92651  Diesel  ...                            0         1
#
# [5 rows x 18 columns]

# %%
final_test.drop(["fuel","transmission","seller_type","brand"],axis=1,inplace=True)
final_test.head()
# Out:
#    km_driven  owner  ...  seller_type_Trustmark Dealer  Popularly
# 0      11000      1  ...                             0          1
# 1      35000      1  ...                             0          1
# 2      80000      1  ...                             0          1
# 3     145241      1  ...                             0          1
# 4      92651      1  ...                             0          1
#
# [5 rows x 14 columns]

# %%
final_test.shape
# Out:
# (2128, 14)

# %% [markdown]
# ##Feature selection

# %%
final_train.columns
# Out:
# Index(['selling_price', 'km_driven', 'owner', 'seats', 'mileage_n', 'engine_n',
#        'max_power_n', 'years_driven', 'fuel_Diesel', 'fuel_LPG', 'fuel_Petrol',
#        'transmission_Manual', 'seller_type_Individual',
#        'seller_type_Trustmark Dealer', 'Popularly'],
#       dtype='object')

# %%
X = final_train.loc[:,['km_driven', 'owner', 'seats', 'mileage_n', 'engine_n',
       'max_power_n', 'years_driven', 'fuel_Diesel', 'fuel_LPG', 'fuel_Petrol',
       'transmission_Manual', 'seller_type_Individual',
       'seller_type_Trustmark Dealer', 'Popularly']]
X.shape
# Out:
# (6000, 14)

# %%
Y = final_train.loc[:,['selling_price']]
Y.head()
# Out:
#    selling_price
# 0         850000
# 1         750000
# 2        1500000
# 3         795000
# 4        3800000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(final_train.corr(),annot=True,cmap='RdYlGn')
plt.show()

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection= ExtraTreesRegressor()
selection.fit(X,Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# ExtraTreesRegressor()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 25)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor()
rf_reg.fit(X_train, Y_train)
Y_pred= rf_reg.predict(X_test)
print("Accuracy on Traing set: ",rf_reg.score(X_train,Y_train))
print("Accuracy on Testing set: ",rf_reg.score(X_test,Y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# Accuracy on Traing set:  0.9959427953645923
# Accuracy on Testing set:  0.9468955194168351

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("\t\tError Table")
print('Mean Squared  Error      : ', metrics.mean_squared_error(Y_test, Y_pred))
print('Root Mean Squared  Error : ', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R Squared Error          : ', metrics.r2_score(Y_test, Y_pred))
# Out:
# 		Error Table
# Mean Squared  Error      :  32648720439.964302
# Root Mean Squared  Error :  180689.56926166022
# R Squared Error          :  0.9468955194168351

# %%
predicted = rf_reg.predict(final_test)
Sample = pd.DataFrame(data={'Id': np.arange(1, final_test.shape[0]+1), 'Predicted': predicted})

Sample.head()
# Out:
#    Id  Predicted
# 0   1  645000.00
# 1   2  824619.99
# 2   3  392439.98
# 3   4  617879.97
# 4   5  580499.97

# %%
Sample.to_csv('final_11.csv', index = False)
